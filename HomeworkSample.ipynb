# %%
data_1.iloc[::10,4]=np.nan
data_1.head()

# %%
# There is 5(Profit) empty data
data_1.isnull().sum()

# %%
## one of the columns then fill with any of the filling techniques  mentioned above(except mean() filling)
 #  each space is filled with the next value
   #  Space left on line 0

data_1 = data.fillna(method = "ffill")
data_1.head()

# %%
data_1.isnull().sum()

# %%
#  Space left on line 0. I will remove that line with dropna method
data_1 = data.dropna(axis =0)
data_1.head()

# %%
a = [1,2,3]
b = [4,5,6]

# %%
a=a.extend(b)
a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-c86c02317d3b> in <module>
# ----> 1 a=a.extend(b)
#       2 a
#
# AttributeError: 'NoneType' object has no attribute 'extend'

# %%
a=a.add(b)
a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-4e6341c48bb9> in <module>
# ----> 1 a=a.add(b)
#       2 a
#
# AttributeError: 'NoneType' object has no attribute 'add'

# %%
a=a.append(b)
a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-f6bb7452a906> in <module>
# ----> 1 a=a.append(b)
#       2 a
#
# AttributeError: 'NoneType' object has no attribute 'append'

# %%
from scipy.spatial.distance import cityblock
import pandas as pd

#define DataFrame
df = pd.DataFrame({'A': [2, 4, 4, 6],
                   'B': [5, 5, 7, 8],
                   'C': [9, 12, 12, 13]})

#calculate Manhattan distance between columns A and B 
cityblock(df.A, df.B)
# Out:
# 9

# %%
from math import sqrt

def manhattan(a, b):
    return sum(abs(x-val2) for val1, val2 in zip(a,b)
# Out:
#   File "<ipython-input-3-3bd796d10b2d>", line 3
#     return sum(abs(x-val2) for val1, val2 in zip(a,b)
#                                                      ^
# SyntaxError: unexpected EOF while parsing

# %%
#define vectors
A = [2, 4, 4, 6]
B = [5, 5, 7, 8]

#calculate Manhattan distance between vectors
manhattan(A, B)

# %%
from scipy.spatial.distance import cityblock
#define vectors
A = [1,2,3,4]
B = [4,3,2,1]
#calculate Manhattan distance between vectors
cityblock(A, B)
# Out:
# 8

# %%
x = pd.Series([1, 2, 3, 4, 5])
y = pd.Series([6, 7, 8, 9, 10])
dist = (np.linalg.norm(x-y))
  
print("Series 1:")
print(x)
  
print("Series 2:")
print(y)

# %%
import numpy as np
import pandas as pd
data =pd.read_csv('50_Startups .csv')
data.head()
# Out:
#    R&D Spend  Administration Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.1    New York  192261.83
# 1  162597.70       151377.59       443898.53  California  191792.06
# 2  153441.51       101145.55       407934.54     Florida  191050.39
# 3  144372.41       118671.85       383199.62    New York  182901.99
# 4  142107.34        91391.77       366168.42     Florida  166187.94

# %% [markdown]
#  Find the mean, df['col1'].mean() and find the standard deviation, df['col1'].std(). Your normalized data would be df['norm_col1']= (df['col1']-df['col1'].mean())/df['col1'].std() –

# %%
import matplotlib.pyplot as plt
data.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
data_copy=data.copy
# Out:
#    R&D Spend  Administration Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.1    New York  192261.83
# 1  162597.70       151377.59       443898.53  California  191792.06
# 2  153441.51       101145.55       407934.54     Florida  191050.39
# 3  144372.41       118671.85       383199.62    New York  182901.99
# 4  142107.34        91391.77       366168.42     Florida  166187.94

# %%
print(data_copy.isnull().values.sum())
# Out:
# 0

# %%
# Let's also check the column-wise distribution of null values:
print(data_copy.isnull().sum())
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
labels = data_copy['Marketing Spend'].astype('category').cat.categories.tolist()
replace_map_comp = {'Marketing Spend': {k: v for k,v in zip(labels,list(range(1,len(labels)+1)))}}
data_copy.replace(replace_map_comp, inplace=True)
print(data_copy.head())
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80               46    New York  192261.83
# 1  162597.70       151377.59               43  California  191792.06
# 2  153441.51       101145.55               42     Florida  191050.39
# 3  144372.41       118671.85               41    New York  182901.99
# 4  142107.34        91391.77               40     Florida  166187.94

# %%
labels = data_copy['State'].astype('category').cat.categories.tolist()
replace_map_comp = {'State': {k: v for k,v in zip(labels,list(range(1,len(labels)+1)))}}
data_copy.replace(replace_map_comp, inplace=True)
print(data_copy.head())
# Out:
#    R&D Spend  Administration  Marketing Spend  State     Profit
# 0  165349.20       136897.80               46      3  192261.83
# 1  162597.70       151377.59               43      1  191792.06
# 2  153441.51       101145.55               42      2  191050.39
# 3  144372.41       118671.85               41      3  182901.99
# 4  142107.34        91391.77               40      2  166187.94

# %%
data_copy['State'].dtypes
# Out:
# dtype('int64')

# %%
data_copy.head()
# Out:
#    R&D Spend  Administration  Marketing Spend  State     Profit
# 0  165349.20       136897.80               46      3  192261.83
# 1  162597.70       151377.59               43      1  191792.06
# 2  153441.51       101145.55               42      2  191050.39
# 3  144372.41       118671.85               41      3  182901.99
# 4  142107.34        91391.77               40      2  166187.94

# %%
from sklearn.preprocessing import MaxAbsScaler

# create an abs_scaler object
abs_scaler = MaxAbsScaler()

# calculate the maximum absolute value for scaling the data using the fit method
abs_scaler.fit(data_copy)

# the maximum absolute values calculated by the fit method
abs_scaler.max_abs_
# array([4.0e+05, 1.7e+01])

# transform the data using the parameters calculated by the fit method (the maximum absolute values)
scaled_data = abs_scaler.transform(data_copy)

# store the results in a data frame
df_scaled = pd.DataFrame(scaled_data, columns =data_copy.columns)

# visualize the data frame
df_scaled.head()
# Out:
#    R&D Spend  Administration  Marketing Spend     State    Profit
# 0   1.000000        0.749527         0.958333  1.000000  1.000000
# 1   0.983359        0.828805         0.895833  0.333333  0.997557
# 2   0.927985        0.553781         0.875000  0.666667  0.993699
# 3   0.873136        0.649738         0.854167  1.000000  0.951317
# 4   0.859438        0.500378         0.833333  0.666667  0.864383

# %%
Normalize numeric columns using at least two normalization techniques mentioned in the chapter

# %%
from sklearn.preprocessing import StandardScaler

# create a scaler object
std_scaler = StandardScaler()
std_scaler
# fit and transform the data
df_std = pd.DataFrame(std_scaler.fit_transform(data_copy), columns=data_copy.columns)

df_std
# Out:
#     R&D Spend  Administration  Marketing Spend     State    Profit
# 0    2.016411        0.560753         1.565574  1.212678  2.011203
# 1    1.955860        1.082807         1.356273 -1.212678  1.999430
# 2    1.754364       -0.728257         1.286506  0.000000  1.980842
# 3    1.554784       -0.096365         1.216738  1.212678  1.776627
# 4    1.504937       -1.079919         1.146971  0.000000  1.357740
# 5    1.279800       -0.776239         1.077204  1.212678  1.127250
# 6    1.340066        0.932147        -1.364645 -1.212678  1.105481
# 7    1.245057        0.871980         0.867903  0.000000  1.096210
# 8    1.030369        0.986952         0.798136  1.212678  1.007470
# 9    1.091819       -0.456640         0.728369 -1.212678  0.946022
# 10   0.620398       -0.387599        -0.318138  0.000000  0.854847
# 11   0.593085       -1.065540        -0.248371 -1.212678  0.808168
# 12   0.443260        0.215449        -0.178604  0.000000  0.741155
# 13   0.402078        0.510179        -0.108837 -1.212678  0.558750
# 14   1.017181        1.269199        -0.039070  0.000000  0.516026
# 15   0.897913        0.045868         0.030698  1.212678  0.448720
# 16   0.094441        0.009118         0.100465 -1.212678  0.375436
# 17   0.460720        0.855666         0.170232  1.212678  0.334771
# 18   0.396725       -0.258465         0.309766  0.000000  0.307116
# 19   0.279442        1.159837        -1.573946  1.212678  0.269773
# 20   0.055726       -0.269588         0.449300 -1.212678  0.161935
# 21   0.102724        1.169186         0.519067  1.212678 -0.017534
# 22   0.006007        0.051850         0.588834  0.000000 -0.041613
# 23  -0.136201       -0.562211         0.658602  0.000000 -0.082169
# 24   0.073115       -0.795469        -1.155343  1.212678 -0.086729
# 25  -0.199312        0.656489        -1.225110 -1.212678 -0.115493
# 26   0.035370        0.821718        -1.294878  0.000000 -0.157367
# 27  -0.035519        0.235069         0.937670  1.212678 -0.175542
# 28  -0.168793        2.210141        -1.434412  0.000000 -0.218798
# 29  -0.178609        1.142457        -1.504179  1.212678 -0.275882
# 30  -0.258074       -0.205629         1.705108  0.000000 -0.302625
# 31  -0.276958        1.130554         1.635341  1.212678 -0.364127
# 32  -0.226949        0.283924         1.495807 -1.212678 -0.365524
# 33  -0.401129       -0.659324        -0.387905  0.000000 -0.381787
# 34  -0.600682        1.310535        -0.457672 -1.212678 -0.383444
# 35  -0.609750       -1.308658        -0.527439  1.212678 -0.389291
# 36  -0.991570        0.205925        -0.597206  0.000000 -0.533932
# 37  -0.652532       -2.525994        -0.666974 -1.212678 -0.552955
# 38  -1.177178       -1.997270        -0.806508  1.212678 -0.771497
# 39  -0.773820       -1.383122        -0.876275 -1.212678 -0.777094
# 40  -0.989577       -0.100900        -0.946042 -1.212678 -0.846411
# 41  -1.008534       -1.320796        -1.015809  0.000000 -0.857466
# 42  -1.102106       -0.906938        -1.085576 -1.212678 -1.015365
# 43  -1.281134        0.217682         1.007437  1.212678 -1.058960
# 44  -1.134305        1.206419         0.239999 -1.212678 -1.173209
# 45  -1.600350        0.101254        -0.736741  1.212678 -1.180082
# 46  -1.593413       -0.199322         0.379533  0.000000 -1.566922
# 47  -1.622362        0.507722        -1.573946 -1.212678 -1.740627
# 48  -1.610433       -2.509409        -1.573946  1.212678 -1.913212
# 49  -1.622362       -0.157226         1.426040 -1.212678 -2.439313
