# %% [markdown]
# ### Objectives:
# ### Categorical Data Labeling on 50_start ups

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('C:/Users/kduisheev/Downloads/P14-Multiple-Linear-Regression/Multiple_Linear_Regression/50_Startups.csv')

# %% [markdown]
# ### Label Encoding

# %% [markdown]
# Statistical calculations can not work on every type of data structures, especially if there are strings, words or characters. In order to make categorical data workable one way to handle this problem is to replace them with numbers. So algorithms can understand and perform meaningful results

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In this example, the first column is country column, which is all text.
# As you might know by now, we can’t have text in our data if we’re going to run any kind of model on it.
# So before we can run a model, we need to make this data ready for the model.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Here we changed france with int zero, and spain with int 1. In case there are many such unique names, numbers can be extended as 0,1,2,3,…
# Above code is the basic algorithm behind how encoding or labeling techniques work
# There are other built in functions that do with same approaches automatically
# Finally categorical column becomes with all numbers

# %% [markdown]
# ### One-Hot Encoder
#
# Though label encoding is straight but it has the disadvantage that the numeric values can be misinterpreted by algorithms as having some sort of hierarchy/order in them. This ordering issue is addressed in another common alternative approach called ‘One-Hot Encoding’. In this strategy, each category value is converted into a new column and assigned a 1 or 0 (notation for true/false) value to the column. Let’s consider the previous example of bridge type and safety levels with one-hot encoding.

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %% [markdown]
# ### Pandas Get dummies for one hot encoding

# %%
df_1 = pd.get_dummies(df,columns=['State'])
df_1.head()
# Out:
#    R&D Spend  Administration  Marketing Spend     Profit  State_California  \
# 0  165349.20       136897.80        471784.10  192261.83                 0
# 1  162597.70       151377.59        443898.53  191792.06                 1
# 2  153441.51       101145.55        407934.54  191050.39                 0
# 3  144372.41       118671.85        383199.62  182901.99                 0
# 4  142107.34        91391.77        366168.42  166187.94                 0
#
#    State_Florida  State_New York
# 0              0               1
# 1              0               0
# 2              1               0
# 3              0               1
# 4              1               0

# %% [markdown]
# ### So, we converted categorical feature into numeric columns, from now we can apply all independent variables for our further predictions
